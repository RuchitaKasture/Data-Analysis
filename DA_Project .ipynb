# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
placment_cell = pd.read_csv("Placement_Data_Full_Class.csv")

# %%
placment_cell
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
len(placment_cell)
# Out:
# 215

# %%
placment_cell.info
# Out:
# <bound method DataFrame.info of      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
placment_cell.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
placment_cell["salary"].quantile(0.1)
# Out:
# np.float64(217400.0)

# %%
placment_cell.iloc[5]
# Out:
# sl_no                      6
# gender                     M
# ssc_p                   55.0
# ssc_b                 Others
# hsc_p                   49.8
# hsc_b                 Others
# hsc_s                Science
# degree_p               67.25
# degree_t            Sci&Tech
# workex                   Yes
# etest_p                 55.0
# specialisation       Mkt&Fin
# mba_p                  51.58
# status            Not Placed
# salary                   NaN
# Name: 5, dtype: object

# %%
placment_cell.iloc[5:8]
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 5      6      M   55.0   Others   49.8   Others   Science     67.25
# 6      7      F   46.0   Others   49.2   Others  Commerce     79.00
# 7      8      M   82.0  Central   64.0  Central   Science     66.00
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 5   Sci&Tech    Yes    55.00        Mkt&Fin  51.58  Not Placed       NaN
# 6  Comm&Mgmt     No    74.28        Mkt&Fin  53.29  Not Placed       NaN
# 7   Sci&Tech    Yes    67.00        Mkt&Fin  62.14      Placed  252000.0

# %%
placment_cell[placment_cell["status"]=="Placed"]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
placment_cell[placment_cell["degree_p"]>60.00]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 5        6      M  55.00   Others  49.80   Others   Science     67.25
# 6        7      F  46.00   Others  49.20   Others  Commerce     79.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 208    209      F  43.00  Central  60.00   Others   Science     65.00
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
plt.figure(figsize=(12,5))
plt.scatter(placment_cell["hsc_p"],placment_cell["degree_t"],marker="^", cmap="plasma")
plt.xlabel("hsc_p")
plt.ylabel("degree_t")
plt.title("Marks")
plt.colorbar(label="hsc_p")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 4))
plt.hist(placment_cell["degree_t"], bins=20, color="red")
plt.xlabel("status")
plt.xticks(range(10, 38, 80))
plt.show()

# %%
plt.pie(placment_cell["hsc_p"], labels=placment_cell["status"],
        colors=["#cc0000","#ff0000","#ff3333","#ff6666","#ff9999","#ffcccc"])
plt.title("specialisation")
plt.show()

# %%
plt.figure(figsize=(14, 6))
plt.bar(placment_cell["gender"],placment_cell["salary"] , width=1, edgecolor="black",
        color=["#cc0000","#ff0000","#ff3333","#ff6666","#ff9999","#ffcccc"])
plt.xlabel("gender")
plt.ylabel("salary")
plt.xticks(range(2,18,9))
plt.title("Salary of Male and Female ")
plt.show()

# %%
plt.figure(figsize=(10,3))
plt.boxplot(placment_cell["degree_p"], vert=False, meanline=True, notch=True, showmeans=True)
plt.xlabel("Degree")
plt.show()

# %%
placment_cell.head
# Out:
# <bound method NDFrame.head of      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
placment_cell["row_id"] =np.arange(2, len(placment_cell)+ 2)
placment_cell.sample(12)
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 142    143      M  85.00  Central   60.0   Others   Science     73.43
# 207    208      M  83.33  Central   78.0   Others  Commerce     61.00
# 109    110      M  52.00  Central   63.0   Others   Science     65.00
# 193    194      F  60.00  Central   63.0  Central      Arts     56.00
# 144    145      M  52.00   Others   50.0   Others      Arts     61.00
# 118    119      M  76.00  Central   80.0  Central   Science     78.00
# 198    199      F  67.00  Central   70.0  Central  Commerce     65.00
# 160    161      M  87.00  Central   74.0  Central   Science     65.00
# 11      12      M  69.60  Central   68.4  Central  Commerce     78.30
# 204    205      F  74.00   Others   73.0   Others  Commerce     73.00
# 102    103      F  77.00   Others   61.0   Others  Commerce     68.00
# 82      83      M  63.00  Central   67.0  Central  Commerce     74.00
#
# ...

# %%
plt.figure(figsize=(10,4))
sns.lineplot(placment_cell["degree_t"])
plt.title("Total Degree Type")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.lineplot(placment_cell, x="sl_no", y="degree_p", hue="status")
plt.title("Total Degree Type")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(placment_cell, x="degree_p", hue="gender")
plt.title("Count of Student Pass In degree")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(placment_cell, x="salary", y="specialisation", hue="gender")
plt.title("working member with spcialisation and the salry")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.kdeplot(placment_cell, x="etest_p",fill= True, hue="status", palette="rocket")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(placment_cell, x="ssc_p", bins=30, kde=True, hue="ssc_b")
plt.xticks(range(40, 90))
plt.show()

# %%
sns.jointplot(placment_cell, x="ssc_p", y="degree_p", height=4, kind="hex")
plt.show()

# %%
plt.figure(figsize=(10,4),facecolor="grey")
sns.violinplot(placment_cell, x="degree_p", y="degree_t", palette="mako", fill=True, )
plt.xticks(range(40,90))
plt.title("Gender By degree Analysis")
plt.show()

# %%
sns.pairplot(placment_cell.drop("sl_no",axis=1),kind="kde", hue="status", palette="rocket")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.catplot(placment_cell, x="status", y="gender",height=4)
plt.show()

# %%
placment_cell.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
#  15  row_id          215 non-null    int64
# dtypes: float64(6), int64(2), object(8)
# ...

# %%
placment_cell.groupby("sl_no")["degree_t"].sum()
# Out:
# sl_no
# 1       Sci&Tech
# 2       Sci&Tech
# 3      Comm&Mgmt
# 4       Sci&Tech
# 5      Comm&Mgmt
#          ...
# 211    Comm&Mgmt
# 212     Sci&Tech
# 213    Comm&Mgmt
# 214    Comm&Mgmt
# 215    Comm&Mgmt
# Name: degree_t, Length: 215, dtype: object

# %%
sns.barplot(placment_cell,x="degree_t",y="degree_p",hue="gender" ,palette="mako")
plt.title("degree type By dgree pass student")
plt.show()

# %%
placment_cell.groupby("specialisation")["row_id"].sum().sort_values().plot.barh(xlabel="row_id")
plt.grid(axis="x")
plt.show()

# %%
placment_cell.groupby("workex")[["etest_p", "mba_p"]].sum().plot.barh(figsize=(8,3),xlabel="etest_p & mba_p")
plt.grid(axis="x")
plt.show()

# %%
placment_cell.groupby("gender")["specialisation"].value_counts().plot.barh()
plt.show()
